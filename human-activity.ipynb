# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/human-activity-recognition-with-smartphones/train.csv
# /kaggle/input/human-activity-recognition-with-smartphones/test.csv

# %%
#Why we use DL when we are already getting 95-96% accuracy using ML model?
#In the classical ML example we used some expert engieered feature. But what if we do not have a domain expert?
#We have to use DL to extract features and find patterns also.

# %%
import pandas as pd
data =pd.read_csv('/kaggle/input/human-activity-recognition-with-smartphones/train.csv')
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
data1= pd.read_csv('/kaggle/input/human-activity-recognition-with-smartphones/test.csv')
data1.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
#Activities is a 6 class labels 
data['Activity'].unique()

Activities= {0:'WALKING',1:'WALKING_UPSTAIRS',2:'WALKING_DOWNSTAIRS',  4:'STANDING', 3:'SITTING', 5:'LAYING'}

# %%
import os 
os.listdir('/kaggle/input/human-activity-recognition-with-smartphones/')
# Out:
# ['train.csv', 'test.csv']

# %% [markdown]
# # *Importing the Data*

# %%
import pandas as pd
import numpy as np

train= pd.read_csv('/kaggle/input/human-activity-recognition-with-smartphones/train.csv')
test= pd.read_csv('/kaggle/input/human-activity-recognition-with-smartphones/test.csv')

print(train.shape)
print(test.shape)
# Out:
# (7352, 563)
# (2947, 563)

# %% [markdown]
# # *Modifying the column names*

# %%
#Modifying the column names

columns= train.columns

columns= columns.str.replace('-', '')
columns= columns.str.replace('(', '')
columns= columns.str.replace(')', '')
columns= columns.str.replace('[,]', '')

train.columns= columns 
test.columns= columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
X_train= train.drop(['subject', 'Activity'], axis=1)
y_train= train.Activity

X_test= test.drop(['subject', 'Activity'], axis=1)
y_test= test.Activity

# %%
print('The format of x_train is {} and shape of y_train is {}'.format(X_train.shape,y_train.shape))
print('The format of x_test is {} and shape of y_test is {}'.format(X_test.shape, y_test.shape))
# Out:
# The format of x_train is (7352, 561) and shape of y_train is (7352,)
# The format of x_test is (2947, 561) and shape of y_test is (2947,)

# %%
#Modelling our Data
#Confusion Matrix function
#Labels are useful in plotting confusion matrix 

labels= ['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
#Function to plot Confusion Matrix 

import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", verticalalignment="center", bbox=dict(facecolor='red', alpha=0.5),
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Generic function to run any model specified
from datetime import datetime
import matplotlib.pyplot as plt

def perform_model(model, x_train, y_train, x_test, y_test, class_labels, cm_normalize=True, print_cm=True, cm_cmap= plt.cm.Greens):
    
    #To store results at various places
    results= dict()
    
    ##Train the model
    train_start_time = datetime.now()
    print('Trainig the model')
    model.fit(x_train, y_train)
    print('Done \n \n')
    train_end_time= datetime.now()
    results['Training_time']= train_end_time- train_start_time
    print('Training_time(HH:MM:SS:ms)- {}\n \n'.format(results['Training_time']))

    #Predict the test data
    test_start_time = datetime.now()
    print('Predicting the test data ')
    y_pred= model.predict(x_test)
    print('Done \n \n')
    test_end_time= datetime.now()
    results['Testing_time']=test_start_time- test_end_time
    print('Testing_time(HH:MM:SS:ms)- {}\n \n'.format(results['Testing_time']))
    results['predicted']= y_pred

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(9,9))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %%
#Method to print Grod Search Attributes
def print_grid_search_attributes(model):
    # Estimator that gave highest score among all the estimators formed in GridSearch
    print('--------------------------')
    print('|      Best Estimator     |')
    print('--------------------------')
    print('\n\t{}\n'.format(model.best_estimator_))  #Gives the whole best model with all its parameters specified


    # parameters that gave best results while performing grid search
    print('--------------------------')
    print('|     Best parameters     |')
    print('--------------------------')
    print('\tParameters of best estimator : \n\n\t{}\n'.format(model.best_params_))   #Gives only the parameters on which we have hyper tuned our model.


    #  number of cross validation splits
    print('---------------------------------')
    print('|   No of CrossValidation sets   |')
    print('--------------------------------')
    print('\n\tTotal number of cross validation sets: {}\n'.format(model.n_splits_))


    # Average cross validated score of the best estimator, from the Grid Search 
    print('--------------------------')
    print('|        Best Score       |')
    print('--------------------------')
    print('\n\tAverage Cross Validate scores of best estimator : \n\n\t{}\n'.format(model.best_score_))

# %% [markdown]
# # **Model Building**

# %% [markdown]
# **1) Logistic Regression**

# %%
#1) Logistic Regression with Grid Search
from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV

# start Grid search
parameters = {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']}   #smaller values of 'C' specify stronger regularization.
log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=3, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# Trainig the model
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py:921: UserWarning: One or more of the test scores are non-finite: [0.91458247        nan 0.93416876        nan 0.93675357        nan
#  0.93335187        nan 0.93430542        nan 0.93267255        nan]
#   category=UserWarning
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Done
#
#
# Training_time(HH:MM:SS:ms)- 0:00:19.797225
#
#
# Predicting the test data
# Done
#
#
# Testing_time(HH:MM:SS:ms)- -1 day, 23:59:59.982744
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9575839837122497
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 428  60   0   0   3]
#  [  0  16 516   0   0   0]
#  [  0   0   0 492   3   1]
#  [  0   0   0   4 401  15]
#  [  0   0   0  22   1 448]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.87      0.92       491
#           STANDING       0.90      0.97      0.93       532
#            WALKING       0.95      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.95      0.97       420
#   WALKING_UPSTAIRS       0.96      0.95      0.96       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
#Plotting its confusion matrix
plt.figure(figsize=(9,9))
plt.grid(b=False)
plot_confusion_matrix(log_reg_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
print_grid_search_attributes(lr_svc_grid_results['model'])

# %% [markdown]
# **2) Linear SVC with Grid Search**

# %%
#2) Linear SVC with Grid Search
from sklearn.svm import LinearSVC

parameters = {'C':[0.125, 0.5, 1, 2, 8, 16]}
lr_svc = LinearSVC(tol=0.00005)
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
lr_svc_grid_results = perform_model(lr_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# Trainig the model
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Done
#
#
# Training_time(HH:MM:SS:ms)- 0:01:16.583091
#
#
# Predicting the test data
# Done
#
#
# Testing_time(HH:MM:SS:ms)- -1 day, 23:59:59.986664
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9674244994910078
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  2 431  55   0   0   3]
#  [  0  10 521   1   0   0]
#  [  0   0   0 496   0   0]
#  [  0   0   0   3 412   5]
#  [  0   0   0  17   0 454]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.88      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947

# %%
print_grid_search_attributes(lr_svc_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LinearSVC(C=0.5, tol=5e-05)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 0.5}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total number of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9419283471376314

# %% [markdown]
# **3) Using rbf Kernel**

# %%
#3) Using rbf Kernel
from sklearn.svm import SVC
parameters = {'C':[2,8,16],  #This is for regularization
              'gamma': [ 0.0078125, 0.125, 2]}   #This is inverseley prportional to sigma

#As γ increases, i.e. σ reduces, the model tends to overfit for a given value of C.
#The RBF kernel function for two points X₁ and X₂ computes the similarity or how close they are to each other. Similar to KNN neighbors.
rbf_svm = SVC(kernel='rbf')
rbf_svm_grid = GridSearchCV(rbf_svm,param_grid=parameters, n_jobs=-1)
rbf_svm_grid_results = perform_model(rbf_svm_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# Trainig the model
# Done
#
#
# Training_time(HH:MM:SS:ms)- 0:05:44.044749
#
#
# Predicting the test data
# Done
#
#
# Testing_time(HH:MM:SS:ms)- -1 day, 23:59:58.647667
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9626739056667798
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 441  48   0   0   2]
#  [  0  12 520   0   0   0]
#  [  0   0   0 489   2   5]
#  [  0   0   0   4 397  19]
#  [  0   0   0  17   1 453]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.90      0.93       491
#           STANDING       0.92      0.98      0.95       532
#            WALKING       0.96      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.95      0.97       420
#   WALKING_UPSTAIRS       0.95      0.96      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
print_grid_search_attributes(rbf_svm_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	SVC(C=16, gamma=0.0078125)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 16, 'gamma': 0.0078125}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total number of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9447834551903698

# %% [markdown]
# **4) Decision Tree Classifier Model**

# %%
#4) Decision Tree Classifier Model

from sklearn.tree import DecisionTreeClassifier
parameters = {'max_depth':np.arange(3,10,2)}
dt = DecisionTreeClassifier()
dt_grid = GridSearchCV(dt,param_grid=parameters, n_jobs=-1)
dt_grid_results = perform_model(dt_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(dt_grid_results['model'])
# Out:
# Trainig the model
# Done
#
#
# Training_time(HH:MM:SS:ms)- 0:00:27.288848
#
#
# Predicting the test data
# Done
#
#
# Testing_time(HH:MM:SS:ms)- -1 day, 23:59:59.990965
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8730912792670512
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 372 119   0   0   0]
#  [  0  59 473   0   0   0]
#  [  0   0   0 475  15   6]
#  [  0   0   0  24 348  48]
#  [  0   0   0  68  35 368]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.86      0.76      0.81       491
#           STANDING       0.80      0.89      0.84       532
#            WALKING       0.84      0.96      0.89       496
# WALKING_DOWNSTAIRS       0.87      0.83      0.85       420
#   WALKING_UPSTAIRS       0.87      0.78      0.82       471
#
#           accuracy                           0.87      2947
#          macro avg       0.87      0.87      0.87      2947
#       weighted avg       0.88      0.87      0.87      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	DecisionTreeClassifier(max_depth=9)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 9}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total number of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.8490303694557362

# %% [markdown]
# **5) Random Forest Classifier**

# %%
#5) Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
params = {'n_estimators': np.arange(10,201,20), 'max_depth':np.arange(3,15,2)}
rfc = RandomForestClassifier()
rfc_grid = GridSearchCV(rfc, param_grid=params, n_jobs=-1)
rfc_grid_results = perform_model(rfc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(rfc_grid_results['model'])
# Out:
# Trainig the model
# Done
#
#
# Training_time(HH:MM:SS:ms)- 0:19:50.569746
#
#
# Predicting the test data
# Done
#
#
# Testing_time(HH:MM:SS:ms)- -1 day, 23:59:59.967778
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9195792331184255
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 431  60   0   0   0]
#  [  0  44 488   0   0   0]
#  [  0   0   0 476  10  10]
#  [  0   0   0  25 352  43]
#  [  0   0   0  40   5 426]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.91      0.88      0.89       491
#           STANDING       0.89      0.92      0.90       532
#            WALKING       0.88      0.96      0.92       496
# WALKING_DOWNSTAIRS       0.96      0.84      0.89       420
#   WALKING_UPSTAIRS       0.89      0.90      0.90       471
#
#           accuracy                           0.92      2947
#          macro avg       0.92      0.92      0.92      2947
#       weighted avg       0.92      0.92      0.92      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	RandomForestClassifier(max_depth=13, n_estimators=50)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 13, 'n_estimators': 50}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total number of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9241072526903352

# %% [markdown]
# **6) Gradient Boosting Classifier**

# %%
#Comparing all the models
print('\n                     Accuracy     Error')
print('                     ----------   --------')
print('Logistic Regression : {:.04}%       {:.04}%'.format(log_reg_grid_results['accuracy'] * 100,\
                                                  100-(log_reg_grid_results['accuracy'] * 100)))

print('Linear SVC          : {:.04}%       {:.04}% '.format(lr_svc_grid_results['accuracy'] * 100,\
                                                        100-(lr_svc_grid_results['accuracy'] * 100)))

print('rbf SVM classifier  : {:.04}%      {:.04}% '.format(rbf_svm_grid_results['accuracy'] * 100,\
                                                          100-(rbf_svm_grid_results['accuracy'] * 100)))

print('DecisionTree        : {:.04}%      {:.04}% '.format(dt_grid_results['accuracy'] * 100,\
                                                        100-(dt_grid_results['accuracy'] * 100)))

print('Random Forest       : {:.04}%      {:.04}% '.format(rfc_grid_results['accuracy'] * 100,\
                                                           100-(rfc_grid_results['accuracy'] * 100)))
# Out:
#                      Accuracy     Error
#                      ----------   --------
# Logistic Regression : 95.76%       4.242%
# Linear SVC          : 96.74%       3.258%
# rbf SVM classifier  : 96.27%      3.733%
# DecisionTree        : 87.31%      12.69%
# Random Forest       : 91.96%      8.042%

# %%
#We can choose Logistic Regression or rbf(Radial Basis Function) Classifier

# %% [markdown]
# # **EDA Analysis and Applying t-sne**

# %%
#EDA Analysis and Applying t-sne
y_train_labels= y_train.map({'WALKING':1, 'WALKING_UPSTAIRS':2,'WALKING_DOWNSTAIRS':3,
                       'SITTING':4, 'STANDING':5,'LAYING':6})

# %%
train= X_train
train['Activity']= y_train_labels
train['Activity_name']= y_train
train['subject']= data['subject']
train.sample()
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 3473        0.27878      -0.017352      -0.111612     -0.997593     -0.990801
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 3473      -0.98813      -0.99787     -0.990483        -0.986      -0.94162
#
#       ...  angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 3473  ...                 -0.118447                         -0.151078
#
#       angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 3473                      -0.240352                          -0.190614
#
#       angleXgravityMean  angleYgravityMean  angleZgravityMean  Activity  \
# 3473          -0.892266           0.020692           0.006367         4
#
#       Activity_name  subject
# 3473        SITTING       17
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %%
#EDA Analysis and Applying t-sne
y_test_labels= y_test.map({'WALKING':1, 'WALKING_UPSTAIRS':2,'WALKING_DOWNSTAIRS':3,
                       'SITTING':4, 'STANDING':5,'LAYING':6})

# %%
test= X_test
test['Activity']= y_test_labels
test['Activity_name']= y_test
test['subject']= data1['subject']
test.sample()
# Out:
#     tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 95       0.333144      -0.043447      -0.126199     -0.363243     -0.096309
#
#     tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 95     -0.390384     -0.392519     -0.054608     -0.346235     -0.308076  ...
#
#     angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 95                 -0.595655                          0.649387
#
#     angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 95                       0.929541                           0.201193
#
#     angleXgravityMean  angleYgravityMean  angleZgravityMean  Activity  \
# 95          -0.670149           0.325928           0.011316         1
#
#     Activity_name  subject
# 95        WALKING        2
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# **Data Cleaning**

# %%
#Data Cleaning
#1)Checking for duplicates
print('There are {} duplicates in the training set'.format(sum(train.duplicated())))
print('There are {} duplicates in the testing set'.format(sum(test.duplicated())))
# Out:
# There are 0 duplicates in the training set
# There are 0 duplicates in the testing set

# %%
#2) Checking for Nan/NULL values
print('We have {} NaN/NULL values in our train data.'.format(train.isnull().values.sum()))
print('We have {} NaN/NULL values in our test data.'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/NULL values in our train data.
# We have 0 NaN/NULL values in our test data.

# %%
#3) Checking for data imbalance
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family']= 'Dejavu Sans'

plt.figure(figsize=(9,9))
plt.title('Data Provided by Each User')
sns.countplot(x='subject', hue='Activity', data=train)
plt.show()

# %%
#Also we find the no of datapoints per activity
plt.title('Distribution of Data Points', fontsize=15)
sns.countplot(train['Activity_name'])
plt.xticks(rotation=90)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'STANDING'),
#   Text(1, 0, 'SITTING'),
#   Text(2, 0, 'LAYING'),
#   Text(3, 0, 'WALKING'),
#   Text(4, 0, 'WALKING_DOWNSTAIRS'),
#   Text(5, 0, 'WALKING_UPSTAIRS')])

# %%
#EDA
#Feature Engineering from Domain Knowledge
#In static Activities like lying, sittingm standing, motion info will not be useful
#Whereas in Dynamic Activities like Walking, WlakingUpstairs, WalkingDiwnstairs, motion info will be very useful

# %%
#Stationary and Moving activities are completely different
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity_name', height=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#3)Magnitude of an acceleration can saperate the classes well
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity_name', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %%
#Observations:

#If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
#If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
#If tAccMean > 0.0 then the Activity is WalkingDownstairs.
#We can classify 75% of the Acitivity labels with some errors.

# %%
#Gravity Acceleration also matters

sns.boxplot(x='Activity_name', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %%
#Observations:

#If angleX,gravityMean > 0 then Activity is Laying.
#We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %% [markdown]
# **Applying t-sne on Data**

# %%
#Applying t-sne on data
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#A second feature of t-SNE is a tuneable parameter, “perplexity,” which says (loosely) how to balance attention between local and global aspects of your data.
#The parameter is, in a sense, a guess about the number of close neighbors each point has.

# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)    #As this is same like PCA it will do the dimensionality reduction and will the x and y coordibate corresponding to each point.
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})   #x is value at x-axis and y is value at y-axis
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','Activity_name'], axis=1)
y_pre_tsne = train['Activity_name']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# [t-SNE] Computed neighbors for 7352 samples in 1.245s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.038s
# [t-SNE] Iteration 50: error = 124.7542038, gradient norm = 0.0257264 (50 iterations in 4.358s)
# [t-SNE] Iteration 100: error = 107.3532715, gradient norm = 0.0302403 (50 iterations in 2.669s)
# [t-SNE] Iteration 150: error = 100.9963989, gradient norm = 0.0190092 (50 iterations in 1.983s)
# [t-SNE] Iteration 200: error = 97.5718842, gradient norm = 0.0167050 (50 iterations in 2.271s)
# [t-SNE] Iteration 250: error = 95.2492523, gradient norm = 0.0134401 (50 iterations in 1.912s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.249252
# [t-SNE] Iteration 300: error = 4.1156983, gradient norm = 0.0015568 (50 iterations in 1.756s)
# [t-SNE] Iteration 350: error = 3.2083783, gradient norm = 0.0009981 (50 iterations in 1.604s)
# [t-SNE] Iteration 400: error = 2.7798109, gradient norm = 0.0007239 (50 iterations in 1.643s)
# [t-SNE] Iteration 450: error = 2.5159626, gradient norm = 0.0005704 (50 iterations in 1.652s)
# [t-SNE] Iteration 500: error = 2.3329849, gradient norm = 0.0004781 (50 iterations in 2.011s)
# [t-SNE] Iteration 550: error = 2.1954951, gradient norm = 0.0004136 (50 iterations in 1.686s)
# [t-SNE] Iteration 600: error = 2.0862014, gradient norm = 0.0003719 (50 iterations in 1.662s)
# [t-SNE] Iteration 650: error = 1.9967641, gradient norm = 0.0003298 (50 iterations in 1.675s)
# [t-SNE] Iteration 700: error = 1.9212070, gradient norm = 0.0003011 (50 iterations in 1.706s)
# [t-SNE] Iteration 750: error = 1.8564030, gradient norm = 0.0002759 (50 iterations in 2.330s)
# [t-SNE] Iteration 800: error = 1.7995106, gradient norm = 0.0002546 (50 iterations in 2.033s)
# [t-SNE] Iteration 850: error = 1.7494608, gradient norm = 0.0002402 (50 iterations in 1.704s)
# [t-SNE] Iteration 900: error = 1.7051668, gradient norm = 0.0002258 (50 iterations in 1.711s)
# [t-SNE] Iteration 950: error = 1.6651889, gradient norm = 0.0002096 (50 iterations in 1.728s)
# [t-SNE] Iteration 1000: error = 1.6287596, gradient norm = 0.0002006 (50 iterations in 1.733s)
# [t-SNE] KL divergence after 1000 iterations: 1.628760
# Done..
# Creating plot for this t-sne visualization..
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# [t-SNE] Computed neighbors for 7352 samples in 1.211s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.054s
# [t-SNE] Iteration 50: error = 114.0784912, gradient norm = 0.0217943 (50 iterations in 4.475s)
# [t-SNE] Iteration 100: error = 97.4151382, gradient norm = 0.0192623 (50 iterations in 1.995s)
# [t-SNE] Iteration 150: error = 93.1219406, gradient norm = 0.0113671 (50 iterations in 1.684s)
# [t-SNE] Iteration 200: error = 91.1806793, gradient norm = 0.0065320 (50 iterations in 1.647s)
# [t-SNE] Iteration 250: error = 90.0058441, gradient norm = 0.0057603 (50 iterations in 1.637s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.005844
# [t-SNE] Iteration 300: error = 3.5714171, gradient norm = 0.0014648 (50 iterations in 1.972s)
# [t-SNE] Iteration 350: error = 2.8125043, gradient norm = 0.0007535 (50 iterations in 1.640s)
# [t-SNE] Iteration 400: error = 2.4314759, gradient norm = 0.0005264 (50 iterations in 1.679s)
# [t-SNE] Iteration 450: error = 2.2141042, gradient norm = 0.0004029 (50 iterations in 1.639s)
# [t-SNE] Iteration 500: error = 2.0699301, gradient norm = 0.0003312 (50 iterations in 1.657s)
# [t-SNE] Iteration 550: error = 1.9647014, gradient norm = 0.0002824 (50 iterations in 1.669s)
# [t-SNE] Iteration 600: error = 1.8838112, gradient norm = 0.0002473 (50 iterations in 2.008s)
# [t-SNE] Iteration 650: error = 1.8189669, gradient norm = 0.0002184 (50 iterations in 1.676s)
# [t-SNE] Iteration 700: error = 1.7651868, gradient norm = 0.0001975 (50 iterations in 2.340s)
# [t-SNE] Iteration 750: error = 1.7199366, gradient norm = 0.0001796 (50 iterations in 1.691s)
# [t-SNE] Iteration 800: error = 1.6809623, gradient norm = 0.0001657 (50 iterations in 1.683s)
# [t-SNE] Iteration 850: error = 1.6470518, gradient norm = 0.0001529 (50 iterations in 1.726s)
# [t-SNE] Iteration 900: error = 1.6172099, gradient norm = 0.0001432 (50 iterations in 2.066s)
# [t-SNE] Iteration 950: error = 1.5907651, gradient norm = 0.0001334 (50 iterations in 1.703s)
# [t-SNE] Iteration 1000: error = 1.5671575, gradient norm = 0.0001262 (50 iterations in 1.688s)
# [t-SNE] KL divergence after 1000 iterations: 1.567158
# Done..
# Creating plot for this t-sne visualization..
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# [t-SNE] Computed neighbors for 7352 samples in 1.236s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.101s
# [t-SNE] Iteration 50: error = 105.9617233, gradient norm = 0.0166956 (50 iterations in 3.426s)
# [t-SNE] Iteration 100: error = 91.2169952, gradient norm = 0.0115338 (50 iterations in 2.510s)
# [t-SNE] Iteration 150: error = 87.6394196, gradient norm = 0.0067732 (50 iterations in 1.898s)
# [t-SNE] Iteration 200: error = 86.2018738, gradient norm = 0.0045614 (50 iterations in 1.774s)
# [t-SNE] Iteration 250: error = 85.4346008, gradient norm = 0.0036465 (50 iterations in 1.765s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.434601
# [t-SNE] Iteration 300: error = 3.1386499, gradient norm = 0.0013891 (50 iterations in 1.797s)
# [t-SNE] Iteration 350: error = 2.4951782, gradient norm = 0.0006469 (50 iterations in 1.732s)
# [t-SNE] Iteration 400: error = 2.1745062, gradient norm = 0.0004210 (50 iterations in 2.086s)
# [t-SNE] Iteration 450: error = 1.9897256, gradient norm = 0.0003161 (50 iterations in 1.737s)
# [t-SNE] Iteration 500: error = 1.8710592, gradient norm = 0.0002526 (50 iterations in 1.742s)
# [t-SNE] Iteration 550: error = 1.7875178, gradient norm = 0.0002084 (50 iterations in 1.755s)
# [t-SNE] Iteration 600: error = 1.7248410, gradient norm = 0.0001810 (50 iterations in 1.758s)
# [t-SNE] Iteration 650: error = 1.6757751, gradient norm = 0.0001604 (50 iterations in 1.805s)
# [t-SNE] Iteration 700: error = 1.6363664, gradient norm = 0.0001435 (50 iterations in 2.746s)
# [t-SNE] Iteration 750: error = 1.6036174, gradient norm = 0.0001303 (50 iterations in 1.769s)
# [t-SNE] Iteration 800: error = 1.5761096, gradient norm = 0.0001191 (50 iterations in 1.777s)
# [t-SNE] Iteration 850: error = 1.5527288, gradient norm = 0.0001094 (50 iterations in 1.773s)
# [t-SNE] Iteration 900: error = 1.5324521, gradient norm = 0.0001030 (50 iterations in 1.789s)
# [t-SNE] Iteration 950: error = 1.5144553, gradient norm = 0.0000956 (50 iterations in 1.923s)
# [t-SNE] Iteration 1000: error = 1.4986364, gradient norm = 0.0000915 (50 iterations in 2.056s)
# [t-SNE] KL divergence after 1000 iterations: 1.498636
# Done..
# Creating plot for this t-sne visualization..
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# [t-SNE] Computed neighbors for 7352 samples in 1.337s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.198s
# [t-SNE] Iteration 50: error = 97.7182159, gradient norm = 0.0168082 (50 iterations in 3.321s)
# [t-SNE] Iteration 100: error = 83.8646317, gradient norm = 0.0061276 (50 iterations in 2.404s)
# [t-SNE] Iteration 150: error = 81.8178101, gradient norm = 0.0033668 (50 iterations in 2.410s)
# [t-SNE] Iteration 200: error = 81.0785522, gradient norm = 0.0020915 (50 iterations in 2.065s)
# [t-SNE] Iteration 250: error = 80.6934052, gradient norm = 0.0020209 (50 iterations in 2.054s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.693405
# [t-SNE] Iteration 300: error = 2.6956723, gradient norm = 0.0012962 (50 iterations in 1.932s)
# [t-SNE] Iteration 350: error = 2.1634114, gradient norm = 0.0005744 (50 iterations in 1.892s)
# [t-SNE] Iteration 400: error = 1.9137027, gradient norm = 0.0003461 (50 iterations in 2.415s)
# [t-SNE] Iteration 450: error = 1.7678359, gradient norm = 0.0002464 (50 iterations in 2.468s)
# [t-SNE] Iteration 500: error = 1.6741649, gradient norm = 0.0001924 (50 iterations in 2.016s)
# [t-SNE] Iteration 550: error = 1.6100905, gradient norm = 0.0001592 (50 iterations in 2.037s)
# [t-SNE] Iteration 600: error = 1.5637208, gradient norm = 0.0001354 (50 iterations in 1.943s)
# [t-SNE] Iteration 650: error = 1.5288262, gradient norm = 0.0001190 (50 iterations in 2.122s)
# [t-SNE] Iteration 700: error = 1.5016899, gradient norm = 0.0001057 (50 iterations in 2.118s)
# [t-SNE] Iteration 750: error = 1.4798920, gradient norm = 0.0000955 (50 iterations in 2.012s)
# [t-SNE] Iteration 800: error = 1.4621582, gradient norm = 0.0000893 (50 iterations in 1.977s)
# [t-SNE] Iteration 850: error = 1.4475698, gradient norm = 0.0000835 (50 iterations in 1.956s)
# [t-SNE] Iteration 900: error = 1.4352453, gradient norm = 0.0000788 (50 iterations in 1.955s)
# [t-SNE] Iteration 950: error = 1.4245321, gradient norm = 0.0000756 (50 iterations in 2.304s)
# [t-SNE] Iteration 1000: error = 1.4156103, gradient norm = 0.0000699 (50 iterations in 2.034s)
# [t-SNE] KL divergence after 1000 iterations: 1.415610
# Done..
# Creating plot for this t-sne visualization..
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# [t-SNE] Computed neighbors for 7352 samples in 1.354s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.498s
# [t-SNE] Iteration 50: error = 87.0730438, gradient norm = 0.0120285 (50 iterations in 3.669s)
# [t-SNE] Iteration 100: error = 75.8386993, gradient norm = 0.0048226 (50 iterations in 3.968s)
# [t-SNE] Iteration 150: error = 74.7511292, gradient norm = 0.0023509 (50 iterations in 2.846s)
# [t-SNE] Iteration 200: error = 74.3339844, gradient norm = 0.0024432 (50 iterations in 3.418s)
# [t-SNE] Iteration 250: error = 74.1408386, gradient norm = 0.0013379 (50 iterations in 3.183s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.140839
# [t-SNE] Iteration 300: error = 2.1565838, gradient norm = 0.0011939 (50 iterations in 2.645s)
# [t-SNE] Iteration 350: error = 1.7555273, gradient norm = 0.0004874 (50 iterations in 2.400s)
# [t-SNE] Iteration 400: error = 1.5858637, gradient norm = 0.0002783 (50 iterations in 2.412s)
# [t-SNE] Iteration 450: error = 1.4920790, gradient norm = 0.0001882 (50 iterations in 2.498s)
# [t-SNE] Iteration 500: error = 1.4323126, gradient norm = 0.0001396 (50 iterations in 2.667s)
# [t-SNE] Iteration 550: error = 1.3911467, gradient norm = 0.0001113 (50 iterations in 2.394s)
# [t-SNE] Iteration 600: error = 1.3619750, gradient norm = 0.0000936 (50 iterations in 2.393s)
# [t-SNE] Iteration 650: error = 1.3406099, gradient norm = 0.0000837 (50 iterations in 2.400s)
# [t-SNE] Iteration 700: error = 1.3249433, gradient norm = 0.0000758 (50 iterations in 2.762s)
# [t-SNE] Iteration 750: error = 1.3133966, gradient norm = 0.0000720 (50 iterations in 2.434s)
# [t-SNE] Iteration 800: error = 1.3048449, gradient norm = 0.0000642 (50 iterations in 2.454s)
# [t-SNE] Iteration 850: error = 1.2976457, gradient norm = 0.0000600 (50 iterations in 3.077s)
# [t-SNE] Iteration 900: error = 1.2915566, gradient norm = 0.0000589 (50 iterations in 2.814s)
# [t-SNE] Iteration 950: error = 1.2865720, gradient norm = 0.0000564 (50 iterations in 2.432s)
# [t-SNE] Iteration 1000: error = 1.2823534, gradient norm = 0.0000525 (50 iterations in 2.404s)
# [t-SNE] KL divergence after 1000 iterations: 1.282353
# Done..
# Creating plot for this t-sne visualization..
# Done

# %%
#All classes are well seperated except the one of standing and sitting.
